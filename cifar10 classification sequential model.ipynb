# %% [markdown]
# ## Objectives:
# * Practice and implement feedforward, multi-layer networks and apply them to the CIFAR-10 dataset
# * Prepare image data for deep learning
# * Learn to use neural network basics (convex functions, loss functions, Gradient descent, Activation functions, Geometric representation)
#
# ### Total Points Possible: 50

# %% [markdown]
# ##Part I: Introduction
# ###1. Import the necessary packages from tensorflow for the following tasks.
# * Build a Sequential model
# * Use Dense hidden layers
# * Use Stochastic Gradient Descent(SDG) optimizer
# * Uuild classification report
# * Import **cifar10** dataset
#  * from tensorflow.keras.datasets import cifar10
#
# ###2. Explore the details about datasets such as cifat10, cifar100
# * https://www.tensorflow.org/datasets/catalog/cifar10
# * https://keras.io/api/datasets/cifar10/
#
# ###3. Understanding Data
# * Based on the exploration of datasets in Part I.2, there are 10 types of images in the dataset {"airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"} identified by the corresponding index numbers.
# * Load the cifar10 dataset into X_train, Y_train, X_test, and Y_test variables
# * Explore the shapes and sizes of the images
# * The images contain rgb components and are 3-dimensional.
# * Print a sample image data, it's dimenstions
# * Print the distinct labels of images in the dataset
# * Display the first 9 images in a neat format (use subplots) and the corresponding labels at the top of each image

# %% [markdown]
# ## Part 2: Preprocessing
# * Convert the pixel data into binary range (0 to 1)
# * Now, convert the 3D image to a vector
# * Also, apply one-hot encoding to convert the labels into vectors of length 10 using **LabelBinarizer**
#
#   * Note: https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelBinarizer.html

# %% [markdown]
# ## Part 3: Define the model
# * Reading:
#  * https://machinelearningmastery.com/choose-an-activation-function-for-deep-learning/
#   * https://machinelearningmastery.com/rectified-linear-activation-function-for-deep-learning-neural-networks/
# * Write a function ${build\_model()}$ to define the architecture of the model using Keras using the following information:
#  * The model is sequential.
#  * $Hidden Layer 1$ contains 1024 Dense neurons, the activation function is $'relu'$
#  * $Hidden Layer 2$ contains 512 Dense neurons with the same activation function as hidden Layer 1
#  * $Output Layer$ is Dense with $'softmax'$ activation function.

# %% [markdown]
# ## Part 4:Train the model (compile and fit)
# * Reading:
#  * https://machinelearningmastery.com/understand-the-dynamics-of-learning-rate-on-deep-learning-neural-networks/
#  * https://machinelearningmastery.com/loss-and-loss-functions-for-training-deep-learning-neural-networks/
# * Train the model:
#  * We use SGD optimizer to train the network with a learning rate set to 0.01, which is the intial choice, and display accuracy of the model.
#  * Use 200 epoches of batch size = 32
#  * The loss function can be of your choice.
# * Save your model for future :
#  * Use model.save() to create a SavedModel folder `my_model`. SavedModel is the more comprehensive save format that saves the model architecture, weights, and the traced Tensorflow subgraphs of the call functions. It enables Keras to restore both built-in layers as well as custom objects.

# %% [markdown]
# ## part 5: Evaluate the model
# * Once the model is trained, let us evaluate it on the testing data and obtain the final classification results including precision, recall, and f-1 score.
# * Plot the loss and accuracy values of training and testing your model.
# * Document your findings from the results.

# %% [markdown]
# ## ** Your Code Follows **.
# * Include as many function defintions as you can and simply call the functions appropriately. It helps make your program precise.
# * For each of the five parts that you code, make your code functional and record your observation using appropriate comment lines such as multiline comments (''' Your comment ''').
# * It is important to comment all parts of your code based on code.
# Note: A list of useful reads befor you begin documentation:
#  * https://www.python.org/dev/peps/pep-0008/
#  * https://www.zenesys.com/blog/coding-standards-and-best-practices-for-python-code-quality
# * You can initially write your code im multiple cells and execute them sequentially.
# * Once the code works, put them all in one cell at the end of all your code and execute it as a single program with appropriate print statements to print all the outputs on one page.

# %% [markdown]
# ## Solution

# %%
## Part 1
# import the necessary packages
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import seaborn as sns


# Part 2:
# load the training and testing data, scale it into the range [0, 1],
# then reshape the design matrix

 ## Your code here ##

'''
Part 2: Loading and preprocessing data
''' 

(x_train, y_train), (x_test, y_test) = cifar10.load_data()


#NORMALIZE 0-1

 ## Your code here ##

x_train = x_train / 255.0
x_test = x_test / 255.0

#flatten images

 ## Your code here ##

# x_train = x_train.flatten()
# x_test = x_test.flatten()

x_train = x_train.reshape(50000, 3072).astype('float32')
x_test = x_test.reshape(10000, 3072).astype('float32')


print(x_train.size, x_test.size)
print(x_train.shape, x_test.shape)

'''
one-hot encoding of labels - categorical attribute
''' 
n_classes = 10
#convert labels from int to one-hot encoding

 ## Your code here ##

lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test_non_binarized = y_test
y_test = lb.transform(y_test)


# create model

model = Sequential()

def build_model():

#    ## Your code here ##
  # model = Sequential()
  model.add(Dense(1024, activation="relu", name = "HiddenLayer1", input_shape = (3072,)))
  model.add(Dense(512, activation="relu", name = "HiddenLayer2"))
  model.add(Dense(10, activation="softmax", name = "OutputLayer"))

  return model

model = build_model()
print(model)
model.summary()

#Part 5 Train model

# train the model using SGD

 ## Your code here ##


opt = SGD(lr = 0.01)
model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=['accuracy'])


# Fit the model

 ## Your code here ##


batch_size = 32
num_classes = 10
epochs = 200

history = model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose = 1, validation_data = (x_test, y_test))


# list all data in history

 ## Your code here ##

history

# saving model

model.save("/content/drive/MyDrive/mymodel")

# summarize history for accuracy
# plot the training loss and accuracy
# summarize history for loss

 ## Your code here ##

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Predict the values from the validation dataset
y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
y_pred_classes = np.argmax(y_pred,axis = 1) 
# Convert validation observations to one hot vectors
y_true = np.argmax(y_test,axis = 1)
# compute the confusion matrix
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred_classes)

classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.figure(figsize=(12, 9))
c = sns.heatmap(confusion_mtx, annot=True, fmt='g')
c.set(xticklabels=classes, yticklabels=classes)

class_report = classification_report(y_true, y_pred_classes)
print(class_report)
# Out:
# 153600000 30720000
# (50000, 3072) (10000, 3072)
# <keras.engine.sequential.Sequential object at 0x7f89f2d6eb90>
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  HiddenLayer1 (Dense)        (None, 1024)              3146752
#
#  HiddenLayer2 (Dense)        (None, 512)               524800
#
#  OutputLayer (Dense)         (None, 10)                5130
#
# =================================================================
# Total params: 3,676,682
# Trainable params: 3,676,682
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 1563/1563 [==============================] - 42s 27ms/step - loss: 1.8416 - accuracy: 0.3433 - val_loss: 1.7573 - val_accuracy: 0.3770
# Epoch 2/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.6557 - accuracy: 0.4145 - val_loss: 1.6380 - val_accuracy: 0.4126
# Epoch 3/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.5744 - accuracy: 0.4444 - val_loss: 1.6017 - val_accuracy: 0.4319
# Epoch 4/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.5141 - accuracy: 0.4658 - val_loss: 1.5542 - val_accuracy: 0.4407
# Epoch 5/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4649 - accuracy: 0.4826 - val_loss: 1.4636 - val_accuracy: 0.4804
# Epoch 6/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.4241 - accuracy: 0.4967 - val_loss: 1.4689 - val_accuracy: 0.4777
# Epoch 7/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3872 - accuracy: 0.5121 - val_loss: 1.4996 - val_accuracy: 0.4649
# Epoch 8/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3561 - accuracy: 0.5202 - val_loss: 1.5221 - val_accuracy: 0.4568
# Epoch 9/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.3250 - accuracy: 0.5337 - val_loss: 1.3721 - val_accuracy: 0.5161
# Epoch 10/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2946 - accuracy: 0.5442 - val_loss: 1.4025 - val_accuracy: 0.5040
# Epoch 11/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2714 - accuracy: 0.5529 - val_loss: 1.4781 - val_accuracy: 0.4692
# Epoch 12/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.2451 - accuracy: 0.5627 - val_loss: 1.4109 - val_accuracy: 0.4938
# Epoch 13/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.2205 - accuracy: 0.5700 - val_loss: 1.3757 - val_accuracy: 0.5131
# Epoch 14/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.1942 - accuracy: 0.5820 - val_loss: 1.3389 - val_accuracy: 0.5201
# Epoch 15/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1705 - accuracy: 0.5876 - val_loss: 1.4054 - val_accuracy: 0.5016
# Epoch 16/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1475 - accuracy: 0.5972 - val_loss: 1.3944 - val_accuracy: 0.5178
# Epoch 17/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 1.1279 - accuracy: 0.6052 - val_loss: 1.3715 - val_accuracy: 0.5170
# Epoch 18/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.1036 - accuracy: 0.6153 - val_loss: 1.5423 - val_accuracy: 0.4775
# Epoch 19/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0815 - accuracy: 0.6218 - val_loss: 1.4078 - val_accuracy: 0.5169
# Epoch 20/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0588 - accuracy: 0.6287 - val_loss: 1.3749 - val_accuracy: 0.5209
# Epoch 21/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.0382 - accuracy: 0.6379 - val_loss: 1.3615 - val_accuracy: 0.5325
# Epoch 22/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 1.0161 - accuracy: 0.6437 - val_loss: 1.3421 - val_accuracy: 0.5299
# Epoch 23/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.9961 - accuracy: 0.6519 - val_loss: 1.3902 - val_accuracy: 0.5171
# Epoch 24/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9733 - accuracy: 0.6603 - val_loss: 1.5494 - val_accuracy: 0.4835
# Epoch 25/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9553 - accuracy: 0.6655 - val_loss: 1.3850 - val_accuracy: 0.5332
# Epoch 26/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9329 - accuracy: 0.6738 - val_loss: 1.3791 - val_accuracy: 0.5303
# Epoch 27/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.9126 - accuracy: 0.6824 - val_loss: 1.4977 - val_accuracy: 0.5024
# Epoch 28/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8912 - accuracy: 0.6905 - val_loss: 1.3542 - val_accuracy: 0.5386
# Epoch 29/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8726 - accuracy: 0.6954 - val_loss: 1.3477 - val_accuracy: 0.5385
# Epoch 30/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8472 - accuracy: 0.7045 - val_loss: 1.3724 - val_accuracy: 0.5427
# Epoch 31/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8247 - accuracy: 0.7173 - val_loss: 1.3924 - val_accuracy: 0.5334
# Epoch 32/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.8120 - accuracy: 0.7177 - val_loss: 1.4264 - val_accuracy: 0.5328
# Epoch 33/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.7860 - accuracy: 0.7295 - val_loss: 1.4133 - val_accuracy: 0.5288
# Epoch 34/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.7693 - accuracy: 0.7327 - val_loss: 1.4302 - val_accuracy: 0.5311
# Epoch 35/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7442 - accuracy: 0.7429 - val_loss: 1.3403 - val_accuracy: 0.5519
# Epoch 36/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7294 - accuracy: 0.7470 - val_loss: 1.3403 - val_accuracy: 0.5461
# Epoch 37/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.7081 - accuracy: 0.7549 - val_loss: 1.3676 - val_accuracy: 0.5470
# Epoch 38/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6867 - accuracy: 0.7618 - val_loss: 1.4520 - val_accuracy: 0.5409
# Epoch 39/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6641 - accuracy: 0.7719 - val_loss: 1.3711 - val_accuracy: 0.5543
# Epoch 40/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6444 - accuracy: 0.7777 - val_loss: 1.4155 - val_accuracy: 0.5474
# Epoch 41/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.6263 - accuracy: 0.7857 - val_loss: 1.4058 - val_accuracy: 0.5558
# Epoch 42/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.6041 - accuracy: 0.7931 - val_loss: 1.5018 - val_accuracy: 0.5288
# Epoch 43/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.5844 - accuracy: 0.8014 - val_loss: 1.4825 - val_accuracy: 0.5483
# Epoch 44/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5709 - accuracy: 0.8062 - val_loss: 1.5456 - val_accuracy: 0.5331
# Epoch 45/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5469 - accuracy: 0.8160 - val_loss: 1.6212 - val_accuracy: 0.5193
# Epoch 46/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5333 - accuracy: 0.8191 - val_loss: 1.4584 - val_accuracy: 0.5520
# Epoch 47/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.5155 - accuracy: 0.8260 - val_loss: 1.5615 - val_accuracy: 0.5334
# Epoch 48/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4939 - accuracy: 0.8345 - val_loss: 1.5975 - val_accuracy: 0.5340
# Epoch 49/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4760 - accuracy: 0.8418 - val_loss: 1.6252 - val_accuracy: 0.5298
# Epoch 50/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4569 - accuracy: 0.8487 - val_loss: 1.6985 - val_accuracy: 0.5201
# Epoch 51/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4413 - accuracy: 0.8549 - val_loss: 1.6385 - val_accuracy: 0.5396
# Epoch 52/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.4247 - accuracy: 0.8607 - val_loss: 1.6033 - val_accuracy: 0.5426
# Epoch 53/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.4065 - accuracy: 0.8674 - val_loss: 1.6638 - val_accuracy: 0.5421
# Epoch 54/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.3896 - accuracy: 0.8727 - val_loss: 1.6633 - val_accuracy: 0.5274
# Epoch 55/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.3776 - accuracy: 0.8770 - val_loss: 1.6354 - val_accuracy: 0.5500
# Epoch 56/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.3562 - accuracy: 0.8855 - val_loss: 1.7349 - val_accuracy: 0.5498
# Epoch 57/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.3478 - accuracy: 0.8890 - val_loss: 1.7126 - val_accuracy: 0.5404
# Epoch 58/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.3314 - accuracy: 0.8946 - val_loss: 1.7288 - val_accuracy: 0.5395
# Epoch 59/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.3151 - accuracy: 0.9006 - val_loss: 1.6391 - val_accuracy: 0.5599
# Epoch 60/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.3007 - accuracy: 0.9054 - val_loss: 1.7441 - val_accuracy: 0.5471
# Epoch 61/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2884 - accuracy: 0.9086 - val_loss: 1.7928 - val_accuracy: 0.5411
# Epoch 62/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2759 - accuracy: 0.9164 - val_loss: 1.7676 - val_accuracy: 0.5559
# Epoch 63/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2652 - accuracy: 0.9174 - val_loss: 1.7594 - val_accuracy: 0.5518
# Epoch 64/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2490 - accuracy: 0.9249 - val_loss: 1.8395 - val_accuracy: 0.5505
# Epoch 65/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2417 - accuracy: 0.9273 - val_loss: 1.8336 - val_accuracy: 0.5497
# Epoch 66/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2283 - accuracy: 0.9312 - val_loss: 1.9234 - val_accuracy: 0.5367
# Epoch 67/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2146 - accuracy: 0.9369 - val_loss: 1.8262 - val_accuracy: 0.5560
# Epoch 68/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.2050 - accuracy: 0.9404 - val_loss: 1.8227 - val_accuracy: 0.5594
# Epoch 69/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1936 - accuracy: 0.9432 - val_loss: 1.7990 - val_accuracy: 0.5644
# Epoch 70/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1872 - accuracy: 0.9465 - val_loss: 1.8666 - val_accuracy: 0.5631
# Epoch 71/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.1789 - accuracy: 0.9494 - val_loss: 1.8234 - val_accuracy: 0.5654
# Epoch 72/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.1620 - accuracy: 0.9559 - val_loss: 1.9713 - val_accuracy: 0.5511
# Epoch 73/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.1569 - accuracy: 0.9576 - val_loss: 1.9112 - val_accuracy: 0.5662
# Epoch 74/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1497 - accuracy: 0.9596 - val_loss: 2.1104 - val_accuracy: 0.5361
# Epoch 75/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1310 - accuracy: 0.9678 - val_loss: 2.0116 - val_accuracy: 0.5440
# Epoch 76/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1289 - accuracy: 0.9673 - val_loss: 2.1948 - val_accuracy: 0.5367
# Epoch 77/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1235 - accuracy: 0.9685 - val_loss: 2.0098 - val_accuracy: 0.5590
# Epoch 78/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1125 - accuracy: 0.9719 - val_loss: 2.1730 - val_accuracy: 0.5547
# Epoch 79/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.1077 - accuracy: 0.9741 - val_loss: 1.9851 - val_accuracy: 0.5685
# Epoch 80/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0998 - accuracy: 0.9765 - val_loss: 2.0655 - val_accuracy: 0.5654
# Epoch 81/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0975 - accuracy: 0.9774 - val_loss: 2.0673 - val_accuracy: 0.5532
# Epoch 82/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0863 - accuracy: 0.9814 - val_loss: 2.0928 - val_accuracy: 0.5585
# Epoch 83/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0826 - accuracy: 0.9822 - val_loss: 2.0292 - val_accuracy: 0.5644
# Epoch 84/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0771 - accuracy: 0.9836 - val_loss: 2.1532 - val_accuracy: 0.5519
# Epoch 85/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0727 - accuracy: 0.9852 - val_loss: 2.1626 - val_accuracy: 0.5565
# Epoch 86/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0692 - accuracy: 0.9862 - val_loss: 2.0969 - val_accuracy: 0.5689
# Epoch 87/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0632 - accuracy: 0.9872 - val_loss: 2.3652 - val_accuracy: 0.5390
# Epoch 88/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0616 - accuracy: 0.9879 - val_loss: 2.1688 - val_accuracy: 0.5708
# Epoch 89/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0544 - accuracy: 0.9902 - val_loss: 2.1868 - val_accuracy: 0.5636
# Epoch 90/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0524 - accuracy: 0.9908 - val_loss: 2.1542 - val_accuracy: 0.5654
# Epoch 91/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0458 - accuracy: 0.9927 - val_loss: 2.2099 - val_accuracy: 0.5681
# Epoch 92/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0435 - accuracy: 0.9931 - val_loss: 2.2281 - val_accuracy: 0.5694
# Epoch 93/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0406 - accuracy: 0.9944 - val_loss: 2.2037 - val_accuracy: 0.5680
# Epoch 94/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0387 - accuracy: 0.9943 - val_loss: 2.2361 - val_accuracy: 0.5564
# Epoch 95/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0355 - accuracy: 0.9956 - val_loss: 2.2259 - val_accuracy: 0.5639
# Epoch 96/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0345 - accuracy: 0.9953 - val_loss: 2.3580 - val_accuracy: 0.5493
# Epoch 97/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0325 - accuracy: 0.9957 - val_loss: 2.2685 - val_accuracy: 0.5734
# Epoch 98/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0293 - accuracy: 0.9967 - val_loss: 2.2684 - val_accuracy: 0.5695
# Epoch 99/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0271 - accuracy: 0.9970 - val_loss: 2.2779 - val_accuracy: 0.5704
# Epoch 100/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0256 - accuracy: 0.9973 - val_loss: 2.2798 - val_accuracy: 0.5707
# Epoch 101/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0236 - accuracy: 0.9978 - val_loss: 2.2968 - val_accuracy: 0.5774
# Epoch 102/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0223 - accuracy: 0.9978 - val_loss: 2.3017 - val_accuracy: 0.5751
# Epoch 103/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0270 - accuracy: 0.9960 - val_loss: 2.3801 - val_accuracy: 0.5578
# Epoch 104/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0239 - accuracy: 0.9980 - val_loss: 2.3245 - val_accuracy: 0.5718
# Epoch 105/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0188 - accuracy: 0.9985 - val_loss: 2.3542 - val_accuracy: 0.5746
# Epoch 106/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0183 - accuracy: 0.9986 - val_loss: 2.3353 - val_accuracy: 0.5723
# Epoch 107/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0176 - accuracy: 0.9987 - val_loss: 2.3531 - val_accuracy: 0.5773
# Epoch 108/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0163 - accuracy: 0.9990 - val_loss: 2.3603 - val_accuracy: 0.5749
# Epoch 109/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0160 - accuracy: 0.9989 - val_loss: 2.3935 - val_accuracy: 0.5740
# Epoch 110/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0144 - accuracy: 0.9992 - val_loss: 2.3841 - val_accuracy: 0.5754
# Epoch 111/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0133 - accuracy: 0.9993 - val_loss: 2.5177 - val_accuracy: 0.5684
# Epoch 112/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0823 - accuracy: 0.9784 - val_loss: 2.3444 - val_accuracy: 0.5709
# Epoch 113/200
# 1563/1563 [==============================] - 37s 24ms/step - loss: 0.0164 - accuracy: 0.9991 - val_loss: 2.3800 - val_accuracy: 0.5745
# Epoch 114/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0138 - accuracy: 0.9993 - val_loss: 2.4397 - val_accuracy: 0.5704
# Epoch 115/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0126 - accuracy: 0.9994 - val_loss: 2.4200 - val_accuracy: 0.5750
# Epoch 116/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0123 - accuracy: 0.9993 - val_loss: 2.4282 - val_accuracy: 0.5760
# Epoch 117/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0112 - accuracy: 0.9995 - val_loss: 2.4368 - val_accuracy: 0.5760
# Epoch 118/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0105 - accuracy: 0.9996 - val_loss: 2.4605 - val_accuracy: 0.5747
# Epoch 119/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0100 - accuracy: 0.9998 - val_loss: 2.4571 - val_accuracy: 0.5752
# Epoch 120/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0093 - accuracy: 0.9998 - val_loss: 2.4582 - val_accuracy: 0.5765
# Epoch 121/200
# 1563/1563 [==============================] - 41s 26ms/step - loss: 0.0090 - accuracy: 0.9998 - val_loss: 2.4857 - val_accuracy: 0.5764
# Epoch 122/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0089 - accuracy: 0.9998 - val_loss: 2.4809 - val_accuracy: 0.5761
# Epoch 123/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0084 - accuracy: 0.9998 - val_loss: 2.4898 - val_accuracy: 0.5788
# Epoch 124/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0084 - accuracy: 0.9998 - val_loss: 2.4945 - val_accuracy: 0.5787
# Epoch 125/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0081 - accuracy: 0.9997 - val_loss: 2.4965 - val_accuracy: 0.5777
# Epoch 126/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0079 - accuracy: 0.9999 - val_loss: 2.5062 - val_accuracy: 0.5774
# Epoch 127/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0076 - accuracy: 0.9999 - val_loss: 2.5161 - val_accuracy: 0.5754
# Epoch 128/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 2.6235 - val_accuracy: 0.5626
# Epoch 129/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 2.5369 - val_accuracy: 0.5761
# Epoch 130/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0068 - accuracy: 0.9999 - val_loss: 2.5286 - val_accuracy: 0.5771
# Epoch 131/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0069 - accuracy: 0.9998 - val_loss: 2.5330 - val_accuracy: 0.5758
# Epoch 132/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 2.5514 - val_accuracy: 0.5789
# Epoch 133/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0065 - accuracy: 0.9998 - val_loss: 2.5527 - val_accuracy: 0.5791
# Epoch 134/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0066 - accuracy: 0.9998 - val_loss: 2.5605 - val_accuracy: 0.5754
# Epoch 135/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0061 - accuracy: 0.9999 - val_loss: 2.5654 - val_accuracy: 0.5774
# Epoch 136/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 2.5835 - val_accuracy: 0.5772
# Epoch 137/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0057 - accuracy: 0.9999 - val_loss: 2.5694 - val_accuracy: 0.5765
# Epoch 138/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 2.5836 - val_accuracy: 0.5781
# Epoch 139/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 2.5781 - val_accuracy: 0.5800
# Epoch 140/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0055 - accuracy: 0.9999 - val_loss: 2.5823 - val_accuracy: 0.5777
# Epoch 141/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 2.5927 - val_accuracy: 0.5768
# Epoch 142/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 2.5974 - val_accuracy: 0.5787
# Epoch 143/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0051 - accuracy: 0.9999 - val_loss: 2.6025 - val_accuracy: 0.5777
# Epoch 144/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0052 - accuracy: 0.9999 - val_loss: 2.6069 - val_accuracy: 0.5759
# Epoch 145/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.6161 - val_accuracy: 0.5787
# Epoch 146/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 2.6388 - val_accuracy: 0.5778
# Epoch 147/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 2.6219 - val_accuracy: 0.5763
# Epoch 148/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.6338 - val_accuracy: 0.5773
# Epoch 149/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 2.6368 - val_accuracy: 0.5790
# Epoch 150/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.6365 - val_accuracy: 0.5772
# Epoch 151/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0046 - accuracy: 0.9999 - val_loss: 2.6456 - val_accuracy: 0.5765
# Epoch 152/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.6425 - val_accuracy: 0.5776
# Epoch 153/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.6545 - val_accuracy: 0.5775
# Epoch 154/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.6571 - val_accuracy: 0.5765
# Epoch 155/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.6618 - val_accuracy: 0.5791
# Epoch 156/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.6667 - val_accuracy: 0.5765
# Epoch 157/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.6699 - val_accuracy: 0.5780
# Epoch 158/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.6750 - val_accuracy: 0.5775
# Epoch 159/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.6771 - val_accuracy: 0.5781
# Epoch 160/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 2.6816 - val_accuracy: 0.5776
# Epoch 161/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6897 - val_accuracy: 0.5782
# Epoch 162/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6863 - val_accuracy: 0.5771
# Epoch 163/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 2.6878 - val_accuracy: 0.5776
# Epoch 164/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.7001 - val_accuracy: 0.5767
# Epoch 165/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.7078 - val_accuracy: 0.5773
# Epoch 166/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.7112 - val_accuracy: 0.5779
# Epoch 167/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 2.7146 - val_accuracy: 0.5768
# Epoch 168/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.7134 - val_accuracy: 0.5775
# Epoch 169/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.7153 - val_accuracy: 0.5766
# Epoch 170/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.7224 - val_accuracy: 0.5758
# Epoch 171/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 2.7309 - val_accuracy: 0.5785
# Epoch 172/200
# 1563/1563 [==============================] - 38s 25ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 2.7359 - val_accuracy: 0.5773
# Epoch 173/200
# 1563/1563 [==============================] - 38s 24ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.7335 - val_accuracy: 0.5769
# Epoch 174/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.7389 - val_accuracy: 0.5775
# Epoch 175/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.7443 - val_accuracy: 0.5773
# Epoch 176/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.7453 - val_accuracy: 0.5760
# Epoch 177/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.7404 - val_accuracy: 0.5773
# Epoch 178/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7554 - val_accuracy: 0.5766
# Epoch 179/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7520 - val_accuracy: 0.5764
# Epoch 180/200
# 1563/1563 [==============================] - 39s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7610 - val_accuracy: 0.5774
# Epoch 181/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.7556 - val_accuracy: 0.5775
# Epoch 182/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.7612 - val_accuracy: 0.5772
# Epoch 183/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.7615 - val_accuracy: 0.5754
# Epoch 184/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 2.7645 - val_accuracy: 0.5771
# Epoch 185/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.7721 - val_accuracy: 0.5790
# Epoch 186/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.7757 - val_accuracy: 0.5776
# Epoch 187/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.7734 - val_accuracy: 0.5770
# Epoch 188/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7811 - val_accuracy: 0.5771
# Epoch 189/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7864 - val_accuracy: 0.5757
# Epoch 190/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7821 - val_accuracy: 0.5755
# Epoch 191/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 2.7918 - val_accuracy: 0.5752
# Epoch 192/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.7937 - val_accuracy: 0.5765
# Epoch 193/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.7961 - val_accuracy: 0.5786
# Epoch 194/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.7991 - val_accuracy: 0.5782
# Epoch 195/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8030 - val_accuracy: 0.5763
# Epoch 196/200
# 1563/1563 [==============================] - 40s 25ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.8035 - val_accuracy: 0.5765
# Epoch 197/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.8057 - val_accuracy: 0.5760
# Epoch 198/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.8099 - val_accuracy: 0.5770
# Epoch 199/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.8178 - val_accuracy: 0.5768
# Epoch 200/200
# 1563/1563 [==============================] - 40s 26ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.8269 - val_accuracy: 0.5776
# WARNING:absl:Function `_wrapped_model` contains input name(s) HiddenLayer1_input with unsupported characters which will be renamed to hiddenlayer1_input in the SavedModel.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/mymodel/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/mymodel/assets
#               precision    recall  f1-score   support
#
#            0       0.63      0.67      0.65      1000
#            1       0.68      0.66      0.67      1000
#            2       0.49      0.47      0.48      1000
#            3       0.41      0.40      0.40      1000
#            4       0.51      0.50      0.51      1000
#            5       0.48      0.48      0.48      1000
#            6       0.61      0.67      0.63      1000
#            7       0.66      0.63      0.64      1000
#            8       0.70      0.70      0.70      1000
#            9       0.62      0.61      0.62      1000
#
#     accuracy                           0.58     10000
#    macro avg       0.58      0.58      0.58     10000
# weighted avg       0.58      0.58      0.58     10000

# %% [markdown]
# After around 50 epochs, test loss increases while accuracy on the test set stays the same indicating that around 50 epochs should have been fine and post that overfitting takes place.

# %% [markdown]
# ##END
